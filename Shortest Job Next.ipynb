# %% [markdown]
# ![Teinstein.png](attachment:Teinstein.png)

# %% [markdown]
# # Shortest Job Next Scheduling Algorithm
#
# Shortest job next (SJN), also known as shortest job first (SJF) or shortest process next (SPN), is a scheduling policy that selects for execution the waiting process with the smallest burst time. SJN is a non-preemptive algorithm.In SJN scheduling, the process with the lowest burst time, among the list of available processes in the ready queue, is going to be scheduled next.
#
# However, it is very difficult to predict the burst time needed for a process hence this algorithm is very difficult to implement in the system.
#
# ### Advantages of SJF
# - Maximum throughput
# - Minimum average waiting and turnaround time
#
# ### Disadvantages of SJF
# - May suffer with the problem of starvation
# - It is not implementable because the exact Burst time for a process can't be known in advance.
#
# ### Sample Input
#
# ![Screenshot%202021-07-02%20at%201.24.29%20PM.png](attachment:Screenshot%202021-07-02%20at%201.24.29%20PM.png)

# %% [markdown]
# ### Predicted Output
#
# ![Screenshot%202021-07-02%20at%201.35.59%20PM.png](attachment:Screenshot%202021-07-02%20at%201.35.59%20PM.png)

# %% [markdown]
# ### Flowchart
#
# ![Screenshot%202021-07-02%20at%204.02.57%20PM.png](attachment:Screenshot%202021-07-02%20at%204.02.57%20PM.png)

# %% [markdown]
# ### Python code
#
# We will discuss the algorithm with the help of a python code.
#
# bt stands for burst time.
#
# We will calculate 4 tables : Processes, Burst time , Waiting time and Turnaround time
#
# Step 1 : Here we take the input of no of processes along with the burst time of each process.

# %%
bt=[]    
n=int(input("Enter the number of process: "))
processes=[]
for i in range(0,n):
 processes.insert(i,i+1)
for i in range(0,n):    
    bt.append(int(input(f"Enter burst time for process {i} : ")))

# %% [markdown]
# Step 2 : Applying bubble sort to sort process according to their burst time so that the process with shortest burst time will be executed first

# %%
for i in range(0,len(bt)-1): 
 for j in range(0,len(bt)-i-1):
  if(bt[j]>bt[j+1]):
   temp=bt[j]
   bt[j]=bt[j+1]
   bt[j+1]=temp
   temp=processes[j]
   processes[j]=processes[j+1]
   processes[j+1]=temp

# %% [markdown]
# Step 3 : Here we initialize the values of wt and tat and calculate their values using the formulas
#
# wt stands for waiting time
#
# avgwt stands for average of waiting time
#
# tat stands for turnaround time
#
# avgtat stands for average of total turnaround time
#
# ### Formulas
#
# turnaround time = completion time - arrival time
#
# waiting time = turnaround time - burst time
#
# average waiting time = total waiting time / no of processes
#
# average turnaround time = total turnaround time / no of processes

# %%
wt=[]    
avgwt=0  
tat=[]    
avgtat=0   
wt.insert(0,0)
tat.insert(0,bt[0])
for i in range(1,len(bt)):  
 wt.insert(i,wt[i-1]+bt[i-1])
 tat.insert(i,wt[i]+bt[i])
 avgwt+=wt[i]
 avgtat+=tat[i]
avgwt=float(avgwt)/n
avgtat=float(avgtat)/n

# %% [markdown]
# Step 4 : Now simply apply FCFS and display the scheduling process

# %%
print("\n")
print("Process\t  Burst Time\t  Waiting Time\t  Turn Around Time\t")
for i in range(0,n):
 print(str(processes[i])+"\t\t"+str(bt[i])+"\t\t"+str(wt[i])+"\t\t"+str(tat[i]))
 print("\n")
print("Average Waiting time is: ", avgwt)
print("Average Turnaround time is: ", avgtat)
